# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
fraud_data = pd.read_csv('/content/Nigerian_Fraud.csv')
fraud_data
# Out:
#                                                  sender              receiver  \
# 0        MR. JAMES NGOLA. <james_ngola2002@maktoob.com>  webmaster@aclweb.org
# 1        Mr. Ben Suleman <bensul2004nng@spinfinder.com>                   R@M
# 2             PRINCE OBONG ELEME <obong_715@epatra.com>  webmaster@aclweb.org
# 3             PRINCE OBONG ELEME <obong_715@epatra.com>  webmaster@aclweb.org
# 4                    Maryam Abacha <m_abacha03@www.com>                   R@M
# ...                                                 ...                   ...
# 3327                      michealagu0255@zipmail.com.br                   NaN
# 3328              ali sherif <ali_sherif252@hotmail.fr>                   NaN
# 3329  Dr Usman Ibrahim Danko <drusmanibrahimtg08@hot...                   NaN
# 3330   Mother Doris Killam <motherdorisk61@hotmail.com>                   NaN
# 3331                                                NaN                   NaN
#
# ...

# %%
fraud_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3332 entries, 0 to 3331
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sender    3001 non-null   object
#  1   receiver  2008 non-null   object
#  2   date      2850 non-null   object
#  3   subject   3293 non-null   object
#  4   body      3332 non-null   object
#  5   urls      3332 non-null   int64
#  6   label     3332 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 182.3+ KB

# %%
# 1. Dataset Shape
print(fraud_data.shape)
# Out:
# (3332, 7)

# %%
# 2. Column Names
print(fraud_data.columns)
# Out:
# Index(['sender', 'receiver', 'date', 'subject', 'body', 'urls', 'label'], dtype='object')

# %%
# 3. First 5 Sample Rows
print(fraud_data.head())
# Out:
#                                            sender              receiver  \
# 0  MR. JAMES NGOLA. <james_ngola2002@maktoob.com>  webmaster@aclweb.org
# 1  Mr. Ben Suleman <bensul2004nng@spinfinder.com>                   R@M
# 2       PRINCE OBONG ELEME <obong_715@epatra.com>  webmaster@aclweb.org
# 3       PRINCE OBONG ELEME <obong_715@epatra.com>  webmaster@aclweb.org
# 4              Maryam Abacha <m_abacha03@www.com>                   R@M
#
#                               date  \
# 0  Thu, 31 Oct 2002 02:38:20 +0000
# 1  Thu, 31 Oct 2002 05:10:00 -0000
# 2  Thu, 31 Oct 2002 22:17:55 +0100
# 3  Thu, 31 Oct 2002 22:44:20 -0000
# 4  Fri, 01 Nov 2002 01:45:04 +0100
#
#                                       subject  \
# 0  URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# 1         URGENT ASSISTANCE /RELATIONSHIP (P)
# 2                             GOOD DAY TO YOU
# 3                             GOOD DAY TO YOU
# 4                     I Need Your Assistance.
#
# ...

# %%
# 4. Class Balance
print("CLASS BALANCE")
# Out:
# CLASS BALANCE
